# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\\Users\\eesha\\Downloads\\train.csv')
# Out:
# C:\Users\eesha\AppData\Local\Temp\ipykernel_14392\866088688.py:1: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\\Users\\eesha\\Downloads\\train.csv')

# %%
df
# Out:
#        DATE (MM/DD)    MST  Global CMP22 (vent/cor) [W/m^2]  \
# 0            01-Jan  00:00                        -0.962276
# 1            01-Jan  00:01                        -0.937921
# 2            01-Jan  00:02                        -0.944395
# 3            01-Jan  00:03                        -0.951350
# 4            01-Jan  00:04                        -0.934976
# ...             ...    ...                              ...
# 527035          NaN    NaN                              NaN
# 527036          NaN    NaN                              NaN
# 527037          NaN    NaN                              NaN
# 527038          NaN    NaN                              NaN
# 527039          NaN    NaN                              NaN
#
#         Direct sNIP [W/m^2]  Azimuth Angle [degrees]  \
# 0                  0.000000                356.85640
# 1                  0.000000                357.65505
# 2                  0.000000                358.45438
# ...

# %%
df[df["DATE (MM/DD)"] == "01-Jan"]
# Out:
#      DATE (MM/DD)    MST  Global CMP22 (vent/cor) [W/m^2]  \
# 0          01-Jan  00:00                        -0.962276
# 1          01-Jan  00:01                        -0.937921
# 2          01-Jan  00:02                        -0.944395
# 3          01-Jan  00:03                        -0.951350
# 4          01-Jan  00:04                        -0.934976
# ...           ...    ...                              ...
# 1435       01-Jan  23:55                        -0.927051
# 1436       01-Jan  23:56                        -0.894522
# 1437       01-Jan  23:57                        -0.921457
# 1438       01-Jan  23:58                        -0.922967
# 1439       01-Jan  23:59                        -0.954779
#
#       Direct sNIP [W/m^2]  Azimuth Angle [degrees]  \
# 0                0.000000                356.85640
# 1                0.000000                357.65505
# 2                0.000000                358.45438
# 3               -0.029673                359.25416
# ...

# %%
df
# Out:
#        DATE (MM/DD)    MST  Global CMP22 (vent/cor) [W/m^2]  \
# 0            01-Jan  00:00                        -0.962276
# 1            01-Jan  00:01                        -0.937921
# 2            01-Jan  00:02                        -0.944395
# 3            01-Jan  00:03                        -0.951350
# 4            01-Jan  00:04                        -0.934976
# ...             ...    ...                              ...
# 527035          NaN    NaN                              NaN
# 527036          NaN    NaN                              NaN
# 527037          NaN    NaN                              NaN
# 527038          NaN    NaN                              NaN
# 527039          NaN    NaN                              NaN
#
#         Direct sNIP [W/m^2]  Azimuth Angle [degrees]  \
# 0                  0.000000                356.85640
# 1                  0.000000                357.65505
# 2                  0.000000                358.45438
# ...

# %%
df =df.dropna()
df
# Out:
#        DATE (MM/DD)    MST  Global CMP22 (vent/cor) [W/m^2]  \
# 0            01-Jan  00:00                        -0.962276
# 1            01-Jan  00:01                        -0.937921
# 2            01-Jan  00:02                        -0.944395
# 3            01-Jan  00:03                        -0.951350
# 4            01-Jan  00:04                        -0.934976
# ...             ...    ...                              ...
# 498235       12-Nov  23:55                        -1.078740
# 498236       12-Nov  23:56                        -1.098090
# 498237       12-Nov  23:57                        -1.113540
# 498238       12-Nov  23:58                        -1.140300
# 498239       12-Nov  23:59                        -1.172780
#
#         Direct sNIP [W/m^2]  Azimuth Angle [degrees]  \
# 0                  0.000000                356.85640
# 1                  0.000000                357.65505
# 2                  0.000000                358.45438
# ...

# %%
id = ['0','1']
j = '0'


for i in range(len(df)):
    row = df.iloc[i]
    if row['DATE (MM/DD)'][-3:] == 'Jan':
        j = '01'
    elif row['DATE (MM/DD)'][-3:] == 'Feb':
        j = '02'
    elif row['DATE (MM/DD)'][-3:] == 'Mar':
        j = '03'
    elif row['DATE (MM/DD)'][-3:] == 'Apr':
        j = '04'
    elif row['DATE (MM/DD)'][-3:] == 'May':
        j = '05'
    elif row['DATE (MM/DD)'][-3:] == 'Jun':
        j = '06'
    elif row['DATE (MM/DD)'][-3:] == 'Jul':
        j = '07'
    elif row['DATE (MM/DD)'][-3:] == 'Aug':
        j = '08'
    elif row['DATE (MM/DD)'][-3:] == 'Sep':
        j = '09'
    elif row['DATE (MM/DD)'][-3:] == 'Oct':
        j = '10'
    elif row['DATE (MM/DD)'][-3:] == 'Nov':
        j = '11'
    elif row['DATE (MM/DD)'][-3:] == 'Dec':
        j = '12'
    id.append(row['DATE (MM/DD)'][:2]+j+row['MST'][:2]+row['MST'][-2:]+'00')

# %%
len(id)
# Out:
# 480933

# %%
df['DATE (MM/DD)'][0][-3:]
# Out:
# 'Jan'

# %%
from keras.applications.vgg19 import VGG19
from tensorflow.keras.models import Model

model = VGG19(input_shape=(224,224,3))
model_new = Model(model.input, model.layers[-2].output)

# %%
id
# Out:
# ['0101000000',
#  '0101000100',
#  '0101000200',
#  '0101000300',
#  '0101000400',
#  '0101000500',
#  '0101000600',
#  '0101000700',
#  '0101000800',
#  '0101000900',
#  '0101001000',
#  '0101001100',
#  '0101001200',
#  '0101001300',
#  '0101001400',
#  '0101001500',
#  '0101001600',
#  '0101001700',
#  '0101001800',
#  '0101001900',
#  '0101002000',
#  '0101002100',
#  '0101002200',
#  '0101002300',
#  '0101002400',
#  '0101002500',
#  '0101002600',
#  '0101002700',
#  '0101002800',
#  '0101002900',
#  '0101003000',
#  '0101003100',
#  '0101003200',
#  '0101003300',
#  '0101003400',
#  '0101003500',
#  '0101003600',
#  '0101003700',
#  '0101003800',
#  '0101003900',
#  '0101004000',
#  '0101004100',
#  '0101004200',
#  '0101004300',
#  '0101004400',
#  '0101004500',
#  '0101004600',
#  '0101004700',
#  '0101004800',
#  '0101004900',
#  '0101005000',
#  '0101005100',
#  '0101005200',
#  '0101005300',
#  '0101005400',
#  '0101005500',
#  '0101005600',
#  '0101005700',
# ...

# %%
list1 = ['str']
for i in range (1000):
    list1.append(('f'+str(i)))

df1 = pd.DataFrame(columns = list1)
df1 = df1.drop(['str'], axis=1)

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions
import numpy as np
import os

j =0


for i in range (len(id)):
    if os.path.exists('C:\\Users\\eesha\\Desktop\\Cogni Dataset\\CCD DATA SET-20230315T195524Z-001\\CCD DATA SET\\'+ id[i][:4] +'\\' + id[i] + '.jpg'):
        img_path = 'C:\\Users\\eesha\\Desktop\\Cogni Dataset\\CCD DATA SET-20230315T195524Z-001\\CCD DATA SET\\'+ id[i][:4] +'\\' + id[i] + '.jpg'
        img = image.load_img(img_path,color_mode='rgb', target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        features = model.predict(x)
        df1.loc[j] = features[0]
        j=  j+1
# Out:
# ...
# 1/1 [==============================] - 1s 506ms/step
# ...
# ...
# 1/1 [==============================] - 1s 1s/step

# %%
df1
# Out:
#                 f0            f1            f2            f3            f4  \
# 0     6.234134e-08  4.431554e-06  9.434175e-06  2.971983e-06  1.822500e-06
# 1     2.170360e-07  6.522901e-06  1.341847e-05  3.291424e-06  2.547511e-06
# 2     3.346826e-07  1.180043e-05  2.612307e-05  7.167652e-06  4.403179e-06
# 3     1.804966e-08  1.525583e-06  3.200012e-06  5.529101e-07  1.728078e-07
# 4     2.494952e-08  2.557723e-06  6.510915e-06  1.424845e-06  1.947297e-06
# ...            ...           ...           ...           ...           ...
# 7492  9.814283e-08  5.130832e-06  3.425827e-06  1.952033e-06  3.492859e-06
# 7493  1.214969e-07  5.077995e-06  2.344426e-06  1.606827e-06  2.786335e-06
# 7494  1.119964e-07  4.929141e-06  2.949546e-06  1.813141e-06  3.438668e-06
# 7495  1.728592e-08  7.619755e-07  3.674738e-07  4.230409e-07  9.694211e-07
# 7496  2.805064e-08  1.220670e-06  7.663355e-07  8.045892e-07  1.636570e-06
#
# ...

# %%
        # img_path = 'C:\\Users\\eesha\\Desktop\\Cogni Dataset\\CCD DATA SET-20230315T195524Z-001\\CCD DATA SET\\0101\\0101074000.jpg'
        # img = image.load_img(img_path,color_mode='rgb', target_size=(224, 224))
        # x = image.img_to_array(img)
        # x.shape
        # x = np.expand_dims(x, axis=0)
        # x = preprocess_input(x)
        # features = model.predict(x)
        # print(features.shape)
        # df1.loc[j] = features[0]

# %%
df1.shape
# Out:
# (7497, 1000)

# %%
len(id)
# Out:
# 480931

# %%
list2 = ['0']

for i in range(len(id)):
    if os.path.exists('C:\\Users\\eesha\\Desktop\\Cogni Dataset\\CCD DATA SET-20230315T195524Z-001\\CCD DATA SET\\'+ id[i][:4] +'\\' + id[i] + '.jpg'):
        list2.append(id[i])
        

list2.pop(0)
# Out:
# '0'

# %%
df1.shape
# Out:
# (7497, 1000)

# %%
df1.index = list2

# %%
df1.shape
# Out:
# (7497, 1000)

# %%
df1
# Out:
#                       f0            f1            f2            f3  \
# 0101074000  6.234134e-08  4.431554e-06  9.434175e-06  2.971983e-06
# 0101075000  2.170360e-07  6.522901e-06  1.341847e-05  3.291424e-06
# 0101080000  3.346826e-07  1.180043e-05  2.612307e-05  7.167652e-06
# 0101081000  1.804966e-08  1.525583e-06  3.200012e-06  5.529101e-07
# 0101082000  2.494952e-08  2.557723e-06  6.510915e-06  1.424845e-06
# ...                  ...           ...           ...           ...
# 1111160000  9.814283e-08  5.130832e-06  3.425827e-06  1.952033e-06
# 1111161000  1.214969e-07  5.077995e-06  2.344426e-06  1.606827e-06
# 1111162000  1.119964e-07  4.929141e-06  2.949546e-06  1.813141e-06
# 1111163000  1.728592e-08  7.619755e-07  3.674738e-07  4.230409e-07
# 1111164000  2.805064e-08  1.220670e-06  7.663355e-07  8.045892e-07
#
#                       f4        f5            f6            f7            f8  \
# 0101074000  1.822500e-06  0.000010  3.314510e-06  4.172545e-07  3.534347e-07
# ...

# %%
df['id'] = id

# %%
df.index = id

# %%
df
# Out:
#            DATE (MM/DD)    MST  Global CMP22 (vent/cor) [W/m^2]  \
# 0101000000       01-Jan  00:00                        -0.962276
# 0101000100       01-Jan  00:01                        -0.937921
# 0101000200       01-Jan  00:02                        -0.944395
# 0101000300       01-Jan  00:03                        -0.951350
# 0101000400       01-Jan  00:04                        -0.934976
# ...                 ...    ...                              ...
# 1211235500       12-Nov  23:55                        -1.078740
# 1211235600       12-Nov  23:56                        -1.098090
# 1211235700       12-Nov  23:57                        -1.113540
# 1211235800       12-Nov  23:58                        -1.140300
# 1211235900       12-Nov  23:59                        -1.172780
#
#             Direct sNIP [W/m^2]  Azimuth Angle [degrees]  \
# 0101000000             0.000000                356.85640
# 0101000100             0.000000                357.65505
# ...

# %%
df2 = pd.merge(df, df1, left_index=True, right_index=True)

# %%
df2.drop(['id'], axis=1)
# Out:
#            DATE (MM/DD)    MST  Global CMP22 (vent/cor) [W/m^2]  \
# 0101074000       01-Jan  07:40                          8.53993
# 0101075000       01-Jan  07:50                         20.59860
# 0101080000       01-Jan  08:00                         28.83560
# 0101081000       01-Jan  08:10                         44.96360
# 0101082000       01-Jan  08:20                         31.37320
# ...                 ...    ...                              ...
# 1111160000       11-Nov  16:00                        104.29900
# 1111161000       11-Nov  16:10                         76.43310
# 1111162000       11-Nov  16:20                         46.91660
# 1111163000       11-Nov  16:30                         13.27720
# 1111164000       11-Nov  16:40                          7.15217
#
#             Direct sNIP [W/m^2]  Azimuth Angle [degrees]  \
# 0101074000             1.078100                122.69154
# 0101075000            -0.143419                124.34405
# ...

# %%
df2.shape
# Out:
# (7497, 1018)

# %%
list3 = df2['Total Cloud Cover [%]']

# %%
np.array(list3)
# Out:
# array([ 0., 13., 25., ...,  4.,  0.,  0.])

# %%
df2 = df2.drop(['Total Cloud Cover [%]', 'DATE (MM/DD)', 'MST'], axis =1)

# %%
# df2.to_csv('C:\\Users\\eesha\\Desktop\\Cogni Dataset\\file1.csv')

# %%
# df2 = df2.astype('float32').dtypes

# %%
X = tf.convert_to_tensor(df2, dtype=tf.float32)
y = tf.convert_to_tensor(list3, dtype = tf.float32)

# %%
X
# Out:
# <tf.Tensor: shape=(7497, 1, 1015), dtype=float32, numpy=
# array([[[ 8.5399303e+00,  1.0781000e+00,  1.2269154e+02, ...,
#           2.7866378e-07,  2.1836108e-06,  3.1994377e-06]],
#
#        [[ 2.0598600e+01, -1.4341900e-01,  1.2434405e+02, ...,
#           4.3141858e-07,  3.2714054e-06,  4.2977049e-06]],
#
#        [[ 2.8835600e+01,  8.2590002e-01,  1.2602976e+02, ...,
#           1.1955477e-06,  3.5710102e-06,  7.0758215e-06]],
#
#        ...,
#
#        [[ 4.6916599e+01,  4.0803000e+02,  2.4288635e+02, ...,
#           8.6753460e-07,  5.5093315e-06,  3.3102806e-05]],
#
#        [[ 1.3277200e+01, -2.7156901e-01,  2.4453027e+02, ...,
#           8.1848242e-08,  1.4348158e-06,  2.5041480e-05]],
#
#        [[ 7.1521702e+00, -7.4064302e-01,  2.4614709e+02, ...,
#           1.6277619e-07,  1.8489824e-06,  3.3012813e-05]]], dtype=float32)>

# %%
train_size = int(len(df2)*0.67)
test_size = len(df2)-(train_size)
trainX, testX = df2[0:train_size], df2[-test_size:]
print(len(trainX), len(testX))
# Out:
# 5022 2475

# %%
y
# Out:
# <tf.Tensor: shape=(7497,), dtype=float32, numpy=array([ 0., 13., 25., ...,  4.,  0.,  0.], dtype=float32)>

# %%
len(testX) + len(trainX) == len(df2)
# Out:
# True

# %%
print(X.shape,y.shape)
# Out:
# (7497, 1, 1015) (7497,)

# %%
Y_train = y[:train_size]
Y_test = y[-test_size:]
print(len(Y_train), len(Y_test))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

model3 = Sequential()
model3.add(LSTM(100, input_shape=(1, 1015)))
# model3.add(LSTM(100))
model3.add(Dense(10))
model3.add(Dense(1))
model3.compile(loss='mean_absolute_error', optimizer = 'adam')
model3.fit(X, y, epochs=1, batch_size=1, verbose=2)
# Out:
# 7497/7497 - 38s - loss: 30.1767 - 38s/epoch - 5ms/step

# %%
pred = model3.predict(X)
# Out:
# 235/235 [==============================] - 2s 7ms/step

# %%
pred
# Out:
# array([[23.154873],
#        [23.154873],
#        [23.154873],
#        ...,
#        [23.154873],
#        [23.154873],
#        [23.154873]], dtype=float32)

# %%
X
# Out:
# <tf.Tensor: shape=(7497, 1, 1015), dtype=float32, numpy=
# array([[[ 8.5399303e+00,  1.0781000e+00,  1.2269154e+02, ...,
#           2.7866378e-07,  2.1836108e-06,  3.1994377e-06]],
#
#        [[ 2.0598600e+01, -1.4341900e-01,  1.2434405e+02, ...,
#           4.3141858e-07,  3.2714054e-06,  4.2977049e-06]],
#
#        [[ 2.8835600e+01,  8.2590002e-01,  1.2602976e+02, ...,
#           1.1955477e-06,  3.5710102e-06,  7.0758215e-06]],
#
#        ...,
#
#        [[ 4.6916599e+01,  4.0803000e+02,  2.4288635e+02, ...,
#           8.6753460e-07,  5.5093315e-06,  3.3102806e-05]],
#
#        [[ 1.3277200e+01, -2.7156901e-01,  2.4453027e+02, ...,
#           8.1848242e-08,  1.4348158e-06,  2.5041480e-05]],
#
#        [[ 7.1521702e+00, -7.4064302e-01,  2.4614709e+02, ...,
#           1.6277619e-07,  1.8489824e-06,  3.3012813e-05]]], dtype=float32)>

# %%
import matplotlib.pyplot as plt

plt.plot(y, color = 'green')
plt.plot(pred, color = 'red')

# %%
X
# Out:
# <tf.Tensor: shape=(7497, 1, 1015), dtype=float32, numpy=
# array([[[ 8.5399303e+00,  1.0781000e+00,  1.2269154e+02, ...,
#           2.7866378e-07,  2.1836108e-06,  3.1994377e-06]],
#
#        [[ 2.0598600e+01, -1.4341900e-01,  1.2434405e+02, ...,
#           4.3141858e-07,  3.2714054e-06,  4.2977049e-06]],
#
#        [[ 2.8835600e+01,  8.2590002e-01,  1.2602976e+02, ...,
#           1.1955477e-06,  3.5710102e-06,  7.0758215e-06]],
#
#        ...,
#
#        [[ 4.6916599e+01,  4.0803000e+02,  2.4288635e+02, ...,
#           8.6753460e-07,  5.5093315e-06,  3.3102806e-05]],
#
#        [[ 1.3277200e+01, -2.7156901e-01,  2.4453027e+02, ...,
#           8.1848242e-08,  1.4348158e-06,  2.5041480e-05]],
#
#        [[ 7.1521702e+00, -7.4064302e-01,  2.4614709e+02, ...,
#           1.6277619e-07,  1.8489824e-06,  3.3012813e-05]]], dtype=float32)>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
scaler.transform(X)
# Out:
# array([[7.70602346e-03, 6.31399537e-03, 2.58679620e-01, ...,
#         2.24618080e-04, 1.11336213e-02, 1.31469713e-04],
#        [1.71088423e-02, 5.15034469e-03, 2.65401545e-01, ...,
#         3.48574733e-04, 1.66834419e-02, 1.76691906e-04],
#        [2.35316910e-02, 6.07374315e-03, 2.72258562e-01, ...,
#         9.68646152e-04, 1.82119962e-02, 2.91083495e-04],
#        ...,
#        [3.76304565e-02, 3.93986940e-01, 7.47598578e-01, ...,
#         7.02471816e-04, 2.81011201e-02, 1.36276930e-03],
#        [1.13999371e-02, 5.02826566e-03, 7.54285589e-01, ...,
#         6.49072653e-05, 7.31334274e-03, 1.03083653e-03],
#        [6.62390932e-03, 4.58141358e-03, 7.60862367e-01, ...,
#         1.30578242e-04, 9.42637994e-03, 1.35906377e-03]])

# %%
X.shape
# Out:
# TensorShape([7497, 1, 1015])

# %%
X = tf.reshape(
    X, (7497,-1)
)

# %%
X = tf.reshape(
    X, (7497,-1, 1015)
)
